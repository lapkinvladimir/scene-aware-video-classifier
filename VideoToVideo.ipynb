# %%
import os
import cv2
import torch
from ultralytics import YOLO


# ОБРАБОТАТЬ ВИДЕО

model = YOLO('yolov8n.pt')  # yolov8s.pt yolov8m.pt yolov8l.pt yolov8x.pt

def process_frame(frame):
    results = model(frame)
    
    annotated_frame = results[0].plot()
    return annotated_frame

def process_video(video_path, output_path):
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        raise FileNotFoundError(f"Не удается открыть файл {video_path}")

    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    fps = cap.get(cv2.CAP_PROP_FPS)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))
    
    current_frame = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        
        current_frame += 1

        annotated_frame = process_frame(frame)
        
        out.write(annotated_frame)

        print(f"Frame num {current_frame} / {total_frames}")
    
    cap.release()
    out.release()
    print(f"Finished. Saved into {output_path}")

video_path = "data/videos/house_4.mov"
output_path = "data/videos/annotation_videos/house_4_1_annotated.mp4"

process_video(video_path, output_path)
# Out:
# 0: 640x352 4 bottles, 448.8ms
# Speed: 41.9ms preprocess, 448.8ms inference, 77.8ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 1 из 302
#
# 0: 640x352 5 bottles, 1 refrigerator, 104.7ms
# Speed: 11.9ms preprocess, 104.7ms inference, 22.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 2 из 302
#
# 0: 640x352 6 bottles, 1 refrigerator, 64.0ms
# Speed: 2.0ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 3 из 302
#
# 0: 640x352 4 bottles, 1 refrigerator, 60.0ms
# Speed: 1.0ms preprocess, 60.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 4 из 302
#
# 0: 640x352 6 bottles, 1 refrigerator, 66.0ms
# Speed: 1.0ms preprocess, 66.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 5 из 302
#
# 0: 640x352 6 bottles, 1 refrigerator, 73.0ms
# Speed: 2.0ms preprocess, 73.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 6 из 302
#
# 0: 640x352 5 bottles, 1 refrigerator, 72.0ms
# Speed: 3.0ms preprocess, 72.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 7 из 302
#
# 0: 640x352 5 bottles, 1 refrigerator, 81.0ms
# Speed: 3.0ms preprocess, 81.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 8 из 302
#
# 0: 640x352 6 bottles, 1 refrigerator, 72.0ms
# Speed: 2.0ms preprocess, 72.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 9 из 302
#
# 0: 640x352 6 bottles, 1 refrigerator, 67.5ms
# Speed: 2.5ms preprocess, 67.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 10 из 302
#
# 0: 640x352 6 bottles, 1 refrigerator, 73.0ms
# Speed: 2.0ms preprocess, 73.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 11 из 302
#
# 0: 640x352 6 bottles, 1 refrigerator, 70.0ms
# Speed: 1.0ms preprocess, 70.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 12 из 302
#
# 0: 640x352 5 bottles, 1 refrigerator, 68.0ms
# Speed: 1.0ms preprocess, 68.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 13 из 302
#
# 0: 640x352 5 bottles, 1 refrigerator, 69.5ms
# Speed: 26.0ms preprocess, 69.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 14 из 302
#
# 0: 640x352 6 bottles, 1 refrigerator, 64.0ms
# Speed: 1.0ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 15 из 302
#
# 0: 640x352 1 person, 6 bottles, 1 refrigerator, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 16 из 302
#
# 0: 640x352 1 person, 6 bottles, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 17 из 302
#
# 0: 640x352 1 person, 6 bottles, 1 refrigerator, 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 18 из 302
#
# 0: 640x352 1 person, 6 bottles, 1 refrigerator, 64.5ms
# Speed: 1.5ms preprocess, 64.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 19 из 302
#
# 0: 640x352 5 bottles, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 20 из 302
#
# 0: 640x352 5 bottles, 1 refrigerator, 68.0ms
# Speed: 2.0ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 21 из 302
#
# 0: 640x352 7 bottles, 1 refrigerator, 66.1ms
# Speed: 1.5ms preprocess, 66.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 22 из 302
#
# 0: 640x352 6 bottles, 1 refrigerator, 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 23 из 302
#
# 0: 640x352 7 bottles, 1 refrigerator, 63.0ms
# Speed: 1.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 24 из 302
#
# 0: 640x352 6 bottles, 63.6ms
# Speed: 2.0ms preprocess, 63.6ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 25 из 302
#
# 0: 640x352 6 bottles, 62.5ms
# Speed: 1.5ms preprocess, 62.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 26 из 302
#
# 0: 640x352 8 bottles, 69.0ms
# Speed: 2.0ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 27 из 302
#
# 0: 640x352 7 bottles, 65.0ms
# Speed: 1.0ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 28 из 302
#
# 0: 640x352 8 bottles, 1 refrigerator, 61.0ms
# Speed: 1.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 29 из 302
#
# 0: 640x352 6 bottles, 106.0ms
# Speed: 2.0ms preprocess, 106.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 30 из 302
#
# 0: 640x352 9 bottles, 68.0ms
# Speed: 2.0ms preprocess, 68.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 31 из 302
#
# 0: 640x352 9 bottles, 1 refrigerator, 61.0ms
# Speed: 1.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 32 из 302
#
# 0: 640x352 9 bottles, 60.0ms
# Speed: 1.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 33 из 302
#
# 0: 640x352 6 bottles, 1 refrigerator, 64.2ms
# Speed: 2.0ms preprocess, 64.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 34 из 302
#
# 0: 640x352 6 bottles, 1 refrigerator, 67.0ms
# Speed: 2.0ms preprocess, 67.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 35 из 302
#
# 0: 640x352 7 bottles, 1 refrigerator, 69.0ms
# Speed: 2.5ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 36 из 302
#
# 0: 640x352 7 bottles, 67.0ms
# Speed: 2.0ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 37 из 302
#
# 0: 640x352 6 bottles, 1 refrigerator, 68.1ms
# Speed: 2.0ms preprocess, 68.1ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 38 из 302
#
# 0: 640x352 7 bottles, 1 refrigerator, 62.1ms
# Speed: 2.0ms preprocess, 62.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 39 из 302
#
# 0: 640x352 7 bottles, 1 refrigerator, 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 40 из 302
#
# 0: 640x352 6 bottles, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 41 из 302
#
# 0: 640x352 7 bottles, 1 refrigerator, 56.0ms
# Speed: 21.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 42 из 302
#
# 0: 640x352 8 bottles, 1 chair, 1 refrigerator, 53.0ms
# Speed: 2.0ms preprocess, 53.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 43 из 302
#
# 0: 640x352 7 bottles, 1 chair, 1 refrigerator, 51.5ms
# Speed: 1.5ms preprocess, 51.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 44 из 302
#
# 0: 640x352 7 bottles, 1 chair, 67.0ms
# Speed: 1.0ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 45 из 302
#
# 0: 640x352 7 bottles, 1 chair, 63.0ms
# Speed: 2.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 46 из 302
#
# 0: 640x352 5 bottles, 1 chair, 1 refrigerator, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 47 из 302
#
# 0: 640x352 5 bottles, 81.0ms
# Speed: 3.0ms preprocess, 81.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 48 из 302
#
# 0: 640x352 5 bottles, 2 chairs, 1 refrigerator, 87.0ms
# Speed: 2.0ms preprocess, 87.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 49 из 302
#
# 0: 640x352 5 bottles, 2 chairs, 74.0ms
# Speed: 2.0ms preprocess, 74.0ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 50 из 302
#
# 0: 640x352 5 bottles, 1 chair, 72.0ms
# Speed: 2.0ms preprocess, 72.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 51 из 302
#
# 0: 640x352 4 bottles, 1 chair, 73.1ms
# Speed: 2.0ms preprocess, 73.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 52 из 302
#
# 0: 640x352 4 bottles, 1 chair, 79.0ms
# Speed: 2.5ms preprocess, 79.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 53 из 302
#
# 0: 640x352 4 bottles, 1 chair, 84.0ms
# Speed: 2.0ms preprocess, 84.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 54 из 302
#
# 0: 640x352 4 bottles, 80.0ms
# Speed: 3.5ms preprocess, 80.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 55 из 302
#
# 0: 640x352 3 bottles, 1 chair, 81.0ms
# Speed: 2.0ms preprocess, 81.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 56 из 302
#
# 0: 640x352 3 bottles, 64.0ms
# Speed: 1.0ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 57 из 302
#
# 0: 640x352 4 bottles, 57.0ms
# Speed: 2.0ms preprocess, 57.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 58 из 302
#
# 0: 640x352 4 bottles, 64.0ms
# Speed: 2.0ms preprocess, 64.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 59 из 302
#
# 0: 640x352 4 bottles, 1 cup, 66.0ms
# Speed: 1.0ms preprocess, 66.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 60 из 302
#
# 0: 640x352 4 bottles, 1 cup, 65.0ms
# Speed: 1.0ms preprocess, 65.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 61 из 302
#
# 0: 640x352 4 bottles, 1 cup, 94.1ms
# Speed: 2.0ms preprocess, 94.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 62 из 302
#
# 0: 640x352 2 bottles, 1 cup, 66.0ms
# Speed: 0.9ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 63 из 302
#
# 0: 640x352 2 bottles, 1 cup, 63.0ms
# Speed: 2.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 64 из 302
#
# 0: 640x352 2 bottles, 1 cup, 63.0ms
# Speed: 2.0ms preprocess, 63.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 65 из 302
#
# 0: 640x352 2 bottles, 1 cup, 64.0ms
# Speed: 2.0ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 66 из 302
#
# 0: 640x352 1 bottle, 67.0ms
# Speed: 2.0ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 67 из 302
#
# 0: 640x352 1 bottle, 1 cup, 64.0ms
# Speed: 2.0ms preprocess, 64.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 68 из 302
#
# 0: 640x352 1 bottle, 1 cup, 74.0ms
# Speed: 5.0ms preprocess, 74.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 69 из 302
#
# 0: 640x352 1 bottle, 1 cup, 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 70 из 302
#
# 0: 640x352 1 bottle, 1 cup, 100.0ms
# Speed: 1.5ms preprocess, 100.0ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 71 из 302
#
# 0: 640x352 1 bottle, 1 cup, 71.0ms
# Speed: 1.0ms preprocess, 71.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 72 из 302
#
# 0: 640x352 1 bottle, 1 cup, 75.1ms
# Speed: 2.0ms preprocess, 75.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 73 из 302
#
# 0: 640x352 1 bottle, 1 cup, 67.0ms
# Speed: 1.0ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 74 из 302
#
# 0: 640x352 1 bottle, 1 cup, 61.5ms
# Speed: 1.5ms preprocess, 61.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 75 из 302
#
# 0: 640x352 1 bottle, 1 cup, 63.9ms
# Speed: 1.0ms preprocess, 63.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 76 из 302
#
# 0: 640x352 1 cup, 63.0ms
# Speed: 2.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 77 из 302
#
# 0: 640x352 1 cup, 64.0ms
# Speed: 1.0ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 78 из 302
#
# 0: 640x352 1 cup, 90.0ms
# Speed: 2.0ms preprocess, 90.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 79 из 302
#
# 0: 640x352 1 cup, 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 80 из 302
#
# 0: 640x352 1 cup, 93.0ms
# Speed: 2.0ms preprocess, 93.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 81 из 302
#
# 0: 640x352 1 cup, 66.5ms
# Speed: 1.5ms preprocess, 66.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 82 из 302
#
# 0: 640x352 1 cup, 65.0ms
# Speed: 2.0ms preprocess, 65.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 83 из 302
#
# 0: 640x352 1 cup, 66.0ms
# Speed: 1.0ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 84 из 302
#
# 0: 640x352 2 cups, 63.0ms
# Speed: 2.0ms preprocess, 63.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 85 из 302
#
# 0: 640x352 1 cup, 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 86 из 302
#
# 0: 640x352 1 cup, 63.0ms
# Speed: 1.5ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 87 из 302
#
# 0: 640x352 1 cup, 67.0ms
# Speed: 2.0ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 88 из 302
#
# 0: 640x352 2 cups, 63.0ms
# Speed: 1.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 89 из 302
#
# 0: 640x352 1 cup, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 90 из 302
#
# 0: 640x352 1 cup, 61.9ms
# Speed: 2.0ms preprocess, 61.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 91 из 302
#
# 0: 640x352 2 cups, 62.8ms
# Speed: 2.0ms preprocess, 62.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 92 из 302
#
# 0: 640x352 2 cups, 62.8ms
# Speed: 1.0ms preprocess, 62.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 93 из 302
#
# 0: 640x352 2 cups, 62.8ms
# Speed: 2.0ms preprocess, 62.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 94 из 302
#
# 0: 640x352 1 cup, 62.8ms
# Speed: 2.0ms preprocess, 62.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 95 из 302
#
# 0: 640x352 1 cup, 1 chair, 63.8ms
# Speed: 2.0ms preprocess, 63.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 96 из 302
#
# 0: 640x352 1 cup, 1 chair, 94.7ms
# Speed: 2.0ms preprocess, 94.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 97 из 302
#
# 0: 640x352 1 cup, 67.8ms
# Speed: 1.0ms preprocess, 67.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 98 из 302
#
# 0: 640x352 1 cup, 1 chair, 64.3ms
# Speed: 2.0ms preprocess, 64.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 99 из 302
#
# 0: 640x352 1 cup, 63.8ms
# Speed: 2.0ms preprocess, 63.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 100 из 302
#
# 0: 640x352 1 cup, 1 chair, 65.3ms
# Speed: 2.0ms preprocess, 65.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 101 из 302
#
# 0: 640x352 1 cup, 1 chair, 66.8ms
# Speed: 2.0ms preprocess, 66.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 102 из 302
#
# 0: 640x352 1 chair, 63.8ms
# Speed: 1.0ms preprocess, 63.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 103 из 302
#
# 0: 640x352 1 cup, 1 chair, 63.3ms
# Speed: 2.0ms preprocess, 63.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 104 из 302
#
# 0: 640x352 1 cup, 1 chair, 64.8ms
# Speed: 1.0ms preprocess, 64.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 105 из 302
#
# 0: 640x352 1 cup, 1 chair, 63.3ms
# Speed: 2.0ms preprocess, 63.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 106 из 302
#
# 0: 640x352 1 chair, 63.8ms
# Speed: 1.0ms preprocess, 63.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 107 из 302
#
# 0: 640x352 1 cup, 63.8ms
# Speed: 2.0ms preprocess, 63.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 108 из 302
#
# 0: 640x352 (no detections), 67.3ms
# Speed: 2.0ms preprocess, 67.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 109 из 302
#
# 0: 640x352 (no detections), 67.8ms
# Speed: 1.0ms preprocess, 67.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 110 из 302
#
# 0: 640x352 (no detections), 92.3ms
# Speed: 1.0ms preprocess, 92.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 111 из 302
#
# 0: 640x352 (no detections), 71.8ms
# Speed: 1.0ms preprocess, 71.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 112 из 302
#
# 0: 640x352 (no detections), 66.8ms
# Speed: 2.0ms preprocess, 66.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 113 из 302
#
# 0: 640x352 (no detections), 64.3ms
# Speed: 1.0ms preprocess, 64.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 114 из 302
#
# 0: 640x352 (no detections), 66.8ms
# Speed: 2.0ms preprocess, 66.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 115 из 302
#
# 0: 640x352 (no detections), 67.3ms
# Speed: 2.0ms preprocess, 67.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 116 из 302
#
# 0: 640x352 (no detections), 65.8ms
# Speed: 2.0ms preprocess, 65.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 117 из 302
#
# 0: 640x352 (no detections), 63.8ms
# Speed: 1.0ms preprocess, 63.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 118 из 302
#
# 0: 640x352 1 bottle, 64.3ms
# Speed: 2.0ms preprocess, 64.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 119 из 302
#
# 0: 640x352 (no detections), 64.8ms
# Speed: 3.0ms preprocess, 64.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 120 из 302
#
# 0: 640x352 (no detections), 66.3ms
# Speed: 1.0ms preprocess, 66.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 121 из 302
#
# 0: 640x352 1 bottle, 65.8ms
# Speed: 1.0ms preprocess, 65.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 122 из 302
#
# 0: 640x352 1 toilet, 63.8ms
# Speed: 2.0ms preprocess, 63.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 123 из 302
#
# 0: 640x352 1 toilet, 93.3ms
# Speed: 2.0ms preprocess, 93.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 124 из 302
#
# 0: 640x352 (no detections), 65.8ms
# Speed: 1.0ms preprocess, 65.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 125 из 302
#
# 0: 640x352 (no detections), 66.3ms
# Speed: 1.0ms preprocess, 66.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 126 из 302
#
# 0: 640x352 (no detections), 64.8ms
# Speed: 2.0ms preprocess, 64.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 127 из 302
#
# 0: 640x352 (no detections), 64.8ms
# Speed: 2.0ms preprocess, 64.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 128 из 302
#
# 0: 640x352 (no detections), 66.3ms
# Speed: 1.0ms preprocess, 66.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 129 из 302
#
# 0: 640x352 (no detections), 65.8ms
# Speed: 1.0ms preprocess, 65.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 130 из 302
#
# 0: 640x352 (no detections), 70.3ms
# Speed: 2.0ms preprocess, 70.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 131 из 302
#
# 0: 640x352 (no detections), 67.8ms
# Speed: 2.0ms preprocess, 67.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 132 из 302
#
# 0: 640x352 (no detections), 64.8ms
# Speed: 1.0ms preprocess, 64.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 133 из 302
#
# 0: 640x352 (no detections), 64.8ms
# Speed: 1.5ms preprocess, 64.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 134 из 302
#
# 0: 640x352 (no detections), 64.8ms
# Speed: 2.0ms preprocess, 64.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 135 из 302
#
# 0: 640x352 (no detections), 94.3ms
# Speed: 2.0ms preprocess, 94.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 136 из 302
#
# 0: 640x352 (no detections), 68.8ms
# Speed: 1.0ms preprocess, 68.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 137 из 302
#
# 0: 640x352 (no detections), 66.3ms
# Speed: 2.0ms preprocess, 66.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 138 из 302
#
# 0: 640x352 (no detections), 67.8ms
# Speed: 1.0ms preprocess, 67.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 139 из 302
#
# 0: 640x352 (no detections), 66.8ms
# Speed: 1.0ms preprocess, 66.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 140 из 302
#
# 0: 640x352 (no detections), 66.3ms
# Speed: 2.0ms preprocess, 66.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 141 из 302
#
# 0: 640x352 (no detections), 64.8ms
# Speed: 2.0ms preprocess, 64.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 142 из 302
#
# 0: 640x352 (no detections), 64.8ms
# Speed: 2.0ms preprocess, 64.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 143 из 302
#
# 0: 640x352 (no detections), 66.8ms
# Speed: 1.0ms preprocess, 66.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 144 из 302
#
# 0: 640x352 (no detections), 68.8ms
# Speed: 2.0ms preprocess, 68.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 145 из 302
#
# 0: 640x352 (no detections), 66.3ms
# Speed: 2.0ms preprocess, 66.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 146 из 302
#
# 0: 640x352 (no detections), 94.7ms
# Speed: 1.0ms preprocess, 94.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 147 из 302
#
# 0: 640x352 (no detections), 66.3ms
# Speed: 1.0ms preprocess, 66.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 148 из 302
#
# 0: 640x352 (no detections), 67.8ms
# Speed: 1.0ms preprocess, 67.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 149 из 302
#
# 0: 640x352 (no detections), 64.8ms
# Speed: 2.0ms preprocess, 64.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 150 из 302
#
# 0: 640x352 (no detections), 66.3ms
# Speed: 2.0ms preprocess, 66.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 151 из 302
#
# 0: 640x352 1 clock, 78.8ms
# Speed: 2.0ms preprocess, 78.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 152 из 302
#
# 0: 640x352 (no detections), 79.3ms
# Speed: 1.0ms preprocess, 79.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 153 из 302
#
# 0: 640x352 1 person, 76.8ms
# Speed: 2.0ms preprocess, 76.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 154 из 302
#
# 0: 640x352 1 person, 83.3ms
# Speed: 2.0ms preprocess, 83.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 155 из 302
#
# 0: 640x352 1 person, 82.8ms
# Speed: 2.0ms preprocess, 82.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 156 из 302
#
# 0: 640x352 1 person, 106.2ms
# Speed: 2.0ms preprocess, 106.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 157 из 302
#
# 0: 640x352 1 person, 77.8ms
# Speed: 2.0ms preprocess, 77.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 158 из 302
#
# 0: 640x352 1 person, 77.3ms
# Speed: 2.0ms preprocess, 77.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 159 из 302
#
# 0: 640x352 1 person, 79.8ms
# Speed: 2.0ms preprocess, 79.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 160 из 302
#
# 0: 640x352 1 person, 82.3ms
# Speed: 2.0ms preprocess, 82.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 161 из 302
#
# 0: 640x352 1 person, 84.8ms
# Speed: 2.0ms preprocess, 84.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 162 из 302
#
# 0: 640x352 1 person, 82.3ms
# Speed: 2.0ms preprocess, 82.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 163 из 302
#
# 0: 640x352 1 person, 77.8ms
# Speed: 2.0ms preprocess, 77.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 164 из 302
#
# 0: 640x352 1 person, 79.3ms
# Speed: 2.0ms preprocess, 79.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 165 из 302
#
# 0: 640x352 1 person, 104.7ms
# Speed: 2.0ms preprocess, 104.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 166 из 302
#
# 0: 640x352 1 person, 77.3ms
# Speed: 2.0ms preprocess, 77.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 167 из 302
#
# 0: 640x352 1 person, 67.8ms
# Speed: 2.0ms preprocess, 67.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 168 из 302
#
# 0: 640x352 1 person, 64.8ms
# Speed: 1.0ms preprocess, 64.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 169 из 302
#
# 0: 640x352 1 person, 63.3ms
# Speed: 1.0ms preprocess, 63.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 170 из 302
#
# 0: 640x352 1 person, 63.8ms
# Speed: 2.0ms preprocess, 63.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 171 из 302
#
# 0: 640x352 (no detections), 64.3ms
# Speed: 2.0ms preprocess, 64.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 172 из 302
#
# 0: 640x352 (no detections), 63.8ms
# Speed: 2.0ms preprocess, 63.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 173 из 302
#
# 0: 640x352 1 person, 64.8ms
# Speed: 1.0ms preprocess, 64.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 174 из 302
#
# 0: 640x352 1 person, 92.3ms
# Speed: 2.0ms preprocess, 92.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 175 из 302
#
# 0: 640x352 1 person, 64.8ms
# Speed: 2.0ms preprocess, 64.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 176 из 302
#
# 0: 640x352 (no detections), 66.3ms
# Speed: 2.0ms preprocess, 66.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 177 из 302
#
# 0: 640x352 (no detections), 64.8ms
# Speed: 1.0ms preprocess, 64.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 178 из 302
#
# 0: 640x352 (no detections), 64.8ms
# Speed: 1.0ms preprocess, 64.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 179 из 302
#
# 0: 640x352 (no detections), 64.3ms
# Speed: 1.0ms preprocess, 64.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 180 из 302
#
# 0: 640x352 (no detections), 66.8ms
# Speed: 1.0ms preprocess, 66.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 181 из 302
#
# 0: 640x352 (no detections), 64.8ms
# Speed: 1.0ms preprocess, 64.8ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 182 из 302
#
# 0: 640x352 (no detections), 64.8ms
# Speed: 2.0ms preprocess, 64.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 183 из 302
#
# 0: 640x352 (no detections), 94.7ms
# Speed: 1.0ms preprocess, 94.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 184 из 302
#
# 0: 640x352 (no detections), 73.3ms
# Speed: 3.0ms preprocess, 73.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 185 из 302
#
# 0: 640x352 (no detections), 77.8ms
# Speed: 2.0ms preprocess, 77.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 186 из 302
#
# 0: 640x352 1 person, 83.3ms
# Speed: 2.0ms preprocess, 83.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 187 из 302
#
# 0: 640x352 1 person, 60.8ms
# Speed: 2.0ms preprocess, 60.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 188 из 302
#
# 0: 640x352 1 person, 56.4ms
# Speed: 2.0ms preprocess, 56.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 189 из 302
#
# 0: 640x352 1 person, 69.8ms
# Speed: 1.0ms preprocess, 69.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 190 из 302
#
# 0: 640x352 1 person, 72.8ms
# Speed: 1.0ms preprocess, 72.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 191 из 302
#
# 0: 640x352 1 person, 101.2ms
# Speed: 1.0ms preprocess, 101.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 192 из 302
#
# 0: 640x352 1 person, 72.8ms
# Speed: 1.0ms preprocess, 72.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 193 из 302
#
# 0: 640x352 1 person, 65.3ms
# Speed: 2.0ms preprocess, 65.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 194 из 302
#
# 0: 640x352 1 person, 61.8ms
# Speed: 2.0ms preprocess, 61.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 195 из 302
#
# 0: 640x352 1 person, 60.8ms
# Speed: 1.0ms preprocess, 60.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 196 из 302
#
# 0: 640x352 (no detections), 67.8ms
# Speed: 1.0ms preprocess, 67.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 197 из 302
#
# 0: 640x352 (no detections), 65.8ms
# Speed: 2.0ms preprocess, 65.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 198 из 302
#
# 0: 640x352 (no detections), 70.3ms
# Speed: 1.0ms preprocess, 70.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 199 из 302
#
# 0: 640x352 (no detections), 93.7ms
# Speed: 2.0ms preprocess, 93.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 200 из 302
#
# 0: 640x352 1 person, 60.3ms
# Speed: 1.0ms preprocess, 60.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 201 из 302
#
# 0: 640x352 1 person, 89.8ms
# Speed: 1.0ms preprocess, 89.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 202 из 302
#
# 0: 640x352 1 refrigerator, 67.8ms
# Speed: 2.0ms preprocess, 67.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 203 из 302
#
# 0: 640x352 (no detections), 68.8ms
# Speed: 2.0ms preprocess, 68.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 204 из 302
#
# 0: 640x352 (no detections), 67.8ms
# Speed: 1.0ms preprocess, 67.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 205 из 302
#
# 0: 640x352 1 refrigerator, 67.3ms
# Speed: 2.0ms preprocess, 67.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 206 из 302
#
# 0: 640x352 1 refrigerator, 66.8ms
# Speed: 1.0ms preprocess, 66.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 207 из 302
#
# 0: 640x352 1 refrigerator, 99.2ms
# Speed: 2.0ms preprocess, 99.2ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 208 из 302
#
# 0: 640x352 1 refrigerator, 67.8ms
# Speed: 1.0ms preprocess, 67.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 209 из 302
#
# 0: 640x352 1 refrigerator, 1 clock, 69.3ms
# Speed: 2.0ms preprocess, 69.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 210 из 302
#
# 0: 640x352 1 clock, 67.8ms
# Speed: 1.0ms preprocess, 67.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 211 из 302
#
# 0: 640x352 1 refrigerator, 68.8ms
# Speed: 2.0ms preprocess, 68.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 212 из 302
#
# 0: 640x352 1 clock, 59.3ms
# Speed: 2.0ms preprocess, 59.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 213 из 302
#
# 0: 640x352 (no detections), 62.8ms
# Speed: 2.0ms preprocess, 62.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 214 из 302
#
# 0: 640x352 1 clock, 93.3ms
# Speed: 2.0ms preprocess, 93.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 215 из 302
#
# 0: 640x352 (no detections), 77.8ms
# Speed: 2.0ms preprocess, 77.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 216 из 302
#
# 0: 640x352 (no detections), 67.3ms
# Speed: 2.0ms preprocess, 67.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 217 из 302
#
# 0: 640x352 (no detections), 64.8ms
# Speed: 2.0ms preprocess, 64.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 218 из 302
#
# 0: 640x352 (no detections), 58.8ms
# Speed: 1.0ms preprocess, 58.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 219 из 302
#
# 0: 640x352 (no detections), 64.3ms
# Speed: 2.0ms preprocess, 64.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 220 из 302
#
# 0: 640x352 (no detections), 90.8ms
# Speed: 1.0ms preprocess, 90.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 221 из 302
#
# 0: 640x352 (no detections), 55.4ms
# Speed: 1.0ms preprocess, 55.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 222 из 302
#
# 0: 640x352 (no detections), 56.8ms
# Speed: 2.0ms preprocess, 56.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 223 из 302
#
# 0: 640x352 (no detections), 60.8ms
# Speed: 2.0ms preprocess, 60.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 224 из 302
#
# 0: 640x352 (no detections), 69.3ms
# Speed: 1.0ms preprocess, 69.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 225 из 302
#
# 0: 640x352 (no detections), 59.8ms
# Speed: 2.0ms preprocess, 59.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 226 из 302
#
# 0: 640x352 (no detections), 69.8ms
# Speed: 2.0ms preprocess, 69.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 227 из 302
#
# 0: 640x352 1 sink, 98.2ms
# Speed: 1.0ms preprocess, 98.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 228 из 302
#
# 0: 640x352 1 sink, 61.8ms
# Speed: 1.0ms preprocess, 61.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 229 из 302
#
# 0: 640x352 (no detections), 61.3ms
# Speed: 1.0ms preprocess, 61.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 230 из 302
#
# 0: 640x352 (no detections), 61.8ms
# Speed: 2.0ms preprocess, 61.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 231 из 302
#
# 0: 640x352 1 sink, 62.8ms
# Speed: 1.0ms preprocess, 62.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 232 из 302
#
# 0: 640x352 1 sink, 62.3ms
# Speed: 1.0ms preprocess, 62.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 233 из 302
#
# 0: 640x352 1 sink, 62.8ms
# Speed: 1.0ms preprocess, 62.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 234 из 302
#
# 0: 640x352 (no detections), 89.3ms
# Speed: 1.0ms preprocess, 89.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 235 из 302
#
# 0: 640x352 (no detections), 63.8ms
# Speed: 1.0ms preprocess, 63.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 236 из 302
#
# 0: 640x352 1 sink, 62.8ms
# Speed: 2.0ms preprocess, 62.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 237 из 302
#
# 0: 640x352 1 bowl, 1 sink, 71.3ms
# Speed: 1.0ms preprocess, 71.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 238 из 302
#
# 0: 640x352 1 bowl, 61.8ms
# Speed: 2.0ms preprocess, 61.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 239 из 302
#
# 0: 640x352 (no detections), 62.3ms
# Speed: 1.0ms preprocess, 62.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 240 из 302
#
# 0: 640x352 1 bowl, 62.8ms
# Speed: 1.0ms preprocess, 62.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 241 из 302
#
# 0: 640x352 1 bowl, 91.8ms
# Speed: 1.0ms preprocess, 91.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 242 из 302
#
# 0: 640x352 1 bowl, 62.3ms
# Speed: 1.0ms preprocess, 62.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 243 из 302
#
# 0: 640x352 1 bowl, 62.8ms
# Speed: 1.0ms preprocess, 62.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 244 из 302
#
# 0: 640x352 1 bowl, 63.3ms
# Speed: 2.0ms preprocess, 63.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 245 из 302
#
# 0: 640x352 1 bowl, 62.8ms
# Speed: 2.0ms preprocess, 62.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 246 из 302
#
# 0: 640x352 1 bowl, 1 chair, 63.8ms
# Speed: 2.0ms preprocess, 63.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 247 из 302
#
# 0: 640x352 (no detections), 64.3ms
# Speed: 1.0ms preprocess, 64.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 248 из 302
#
# 0: 640x352 (no detections), 89.8ms
# Speed: 2.0ms preprocess, 89.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 249 из 302
#
# 0: 640x352 1 bowl, 1 tv, 61.3ms
# Speed: 2.0ms preprocess, 61.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 250 из 302
#
# 0: 640x352 1 bowl, 1 tv, 63.8ms
# Speed: 1.0ms preprocess, 63.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 251 из 302
#
# 0: 640x352 1 bowl, 1 tv, 63.8ms
# Speed: 1.0ms preprocess, 63.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 252 из 302
#
# 0: 640x352 3 bowls, 63.3ms
# Speed: 1.0ms preprocess, 63.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 253 из 302
#
# 0: 640x352 3 bowls, 1 tv, 1 sink, 63.8ms
# Speed: 2.0ms preprocess, 63.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 254 из 302
#
# 0: 640x352 3 bowls, 1 sink, 63.3ms
# Speed: 1.0ms preprocess, 63.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 255 из 302
#
# 0: 640x352 3 bowls, 1 sink, 93.7ms
# Speed: 1.0ms preprocess, 93.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 256 из 302
#
# 0: 640x352 3 bowls, 62.8ms
# Speed: 1.0ms preprocess, 62.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 257 из 302
#
# 0: 640x352 2 bowls, 62.3ms
# Speed: 1.0ms preprocess, 62.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 258 из 302
#
# 0: 640x352 2 bowls, 1 microwave, 63.8ms
# Speed: 1.0ms preprocess, 63.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 259 из 302
#
# 0: 640x352 3 bowls, 1 tv, 63.3ms
# Speed: 2.0ms preprocess, 63.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 260 из 302
#
# 0: 640x352 3 bowls, 62.8ms
# Speed: 1.0ms preprocess, 62.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 261 из 302
#
# 0: 640x352 3 bowls, 1 tv, 62.8ms
# Speed: 1.0ms preprocess, 62.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 262 из 302
#
# 0: 640x352 2 bowls, 1 tv, 1 microwave, 101.2ms
# Speed: 1.0ms preprocess, 101.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 263 из 302
#
# 0: 640x352 2 bowls, 1 tv, 1 microwave, 65.8ms
# Speed: 2.0ms preprocess, 65.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 264 из 302
#
# 0: 640x352 3 bowls, 2 tvs, 1 microwave, 63.3ms
# Speed: 1.0ms preprocess, 63.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 265 из 302
#
# 0: 640x352 3 bowls, 1 chair, 1 tv, 1 microwave, 64.8ms
# Speed: 2.0ms preprocess, 64.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 266 из 302
#
# 0: 640x352 2 bowls, 1 chair, 1 tv, 1 microwave, 63.8ms
# Speed: 1.0ms preprocess, 63.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 267 из 302
#
# 0: 640x352 3 bowls, 1 chair, 1 microwave, 61.8ms
# Speed: 2.0ms preprocess, 61.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 268 из 302
#
# 0: 640x352 2 bowls, 2 microwaves, 63.8ms
# Speed: 2.0ms preprocess, 63.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 269 из 302
#
# 0: 640x352 2 bowls, 1 microwave, 92.3ms
# Speed: 1.0ms preprocess, 92.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 270 из 302
#
# 0: 640x352 2 bowls, 1 tv, 1 microwave, 1 book, 68.8ms
# Speed: 1.0ms preprocess, 68.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 271 из 302
#
# 0: 640x352 2 bowls, 1 microwave, 1 book, 74.3ms
# Speed: 2.0ms preprocess, 74.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 272 из 302
#
# 0: 640x352 3 bowls, 1 microwave, 1 book, 75.8ms
# Speed: 2.0ms preprocess, 75.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 273 из 302
#
# 0: 640x352 1 cup, 2 bowls, 1 microwave, 1 book, 92.3ms
# Speed: 2.0ms preprocess, 92.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 274 из 302
#
# 0: 640x352 2 bowls, 1 microwave, 126.7ms
# Speed: 2.0ms preprocess, 126.7ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 275 из 302
#
# 0: 640x352 1 cup, 2 bowls, 1 microwave, 1 book, 66.3ms
# Speed: 2.0ms preprocess, 66.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 276 из 302
#
# 0: 640x352 3 bowls, 1 chair, 1 microwave, 1 book, 69.8ms
# Speed: 1.0ms preprocess, 69.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 277 из 302
#
# 0: 640x352 3 bowls, 2 chairs, 1 tv, 1 microwave, 85.3ms
# Speed: 2.0ms preprocess, 85.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 278 из 302
#
# 0: 640x352 2 bowls, 1 chair, 2 tvs, 1 microwave, 1 book, 71.8ms
# Speed: 2.0ms preprocess, 71.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 279 из 302
#
# 0: 640x352 2 bowls, 1 chair, 1 tv, 1 microwave, 1 book, 108.2ms
# Speed: 2.0ms preprocess, 108.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 280 из 302
#
# 0: 640x352 2 bowls, 1 chair, 1 microwave, 1 book, 66.8ms
# Speed: 1.0ms preprocess, 66.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 281 из 302
#
# 0: 640x352 4 bowls, 1 chair, 1 tv, 1 microwave, 1 book, 56.4ms
# Speed: 2.0ms preprocess, 56.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 282 из 302
#
# 0: 640x352 3 bowls, 1 chair, 2 tvs, 1 book, 63.8ms
# Speed: 2.0ms preprocess, 63.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 283 из 302
#
# 0: 640x352 2 bowls, 1 chair, 1 tv, 1 book, 65.8ms
# Speed: 2.0ms preprocess, 65.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 284 из 302
#
# 0: 640x352 3 bowls, 1 chair, 1 microwave, 1 book, 57.4ms
# Speed: 2.0ms preprocess, 57.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 285 из 302
#
# 0: 640x352 3 bowls, 1 chair, 1 tv, 1 microwave, 1 book, 103.7ms
# Speed: 2.0ms preprocess, 103.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 286 из 302
#
# 0: 640x352 2 bowls, 1 chair, 1 microwave, 1 book, 76.3ms
# Speed: 1.0ms preprocess, 76.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 287 из 302
#
# 0: 640x352 2 bowls, 1 chair, 1 microwave, 1 book, 61.8ms
# Speed: 1.0ms preprocess, 61.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 288 из 302
#
# 0: 640x352 2 bowls, 1 chair, 1 laptop, 1 microwave, 58.8ms
# Speed: 1.0ms preprocess, 58.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 289 из 302
#
# 0: 640x352 2 bowls, 1 chair, 1 microwave, 1 book, 54.9ms
# Speed: 1.0ms preprocess, 54.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 290 из 302
#
# 0: 640x352 2 bowls, 1 chair, 1 microwave, 65.8ms
# Speed: 2.0ms preprocess, 65.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 291 из 302
#
# 0: 640x352 2 bowls, 1 chair, 1 microwave, 102.2ms
# Speed: 1.0ms preprocess, 102.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 292 из 302
#
# 0: 640x352 2 bowls, 2 chairs, 1 microwave, 63.8ms
# Speed: 2.0ms preprocess, 63.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 293 из 302
#
# 0: 640x352 2 bowls, 2 chairs, 1 microwave, 70.3ms
# Speed: 1.0ms preprocess, 70.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 294 из 302
#
# 0: 640x352 1 bottle, 2 bowls, 2 chairs, 1 microwave, 71.8ms
# Speed: 1.0ms preprocess, 71.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 295 из 302
#
# 0: 640x352 1 bottle, 2 bowls, 1 chair, 1 microwave, 69.8ms
# Speed: 2.0ms preprocess, 69.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 296 из 302
#
# 0: 640x352 1 bottle, 2 bowls, 1 chair, 1 microwave, 100.7ms
# Speed: 1.0ms preprocess, 100.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 297 из 302
#
# 0: 640x352 1 bottle, 2 bowls, 1 chair, 1 microwave, 70.8ms
# Speed: 2.0ms preprocess, 70.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 298 из 302
#
# 0: 640x352 1 bottle, 2 bowls, 2 chairs, 1 microwave, 1 book, 71.8ms
# Speed: 2.0ms preprocess, 71.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 299 из 302
#
# 0: 640x352 2 bowls, 2 chairs, 1 microwave, 72.8ms
# Speed: 2.0ms preprocess, 72.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 300 из 302
#
# 0: 640x352 2 bowls, 1 chair, 1 microwave, 1 book, 69.3ms
# Speed: 1.0ms preprocess, 69.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 301 из 302
#
# 0: 640x352 2 bowls, 1 chair, 1 microwave, 64.8ms
# Speed: 1.0ms preprocess, 64.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 302 из 302
# Finished. Saved into data/videos/annotation_videos/house_4_1_annotated.mp4

# %%
import cv2
import numpy as np

# ОТКРЫТЬ ВИДЕО

video_path_1 = 'data/videos/house_1.MOV'
video_path_2 = 'data/videos/annotation_videos/house_1_1_annotated.mp4'

cap1 = cv2.VideoCapture(video_path_1)
cap2 = cv2.VideoCapture(video_path_2)

# if not cap1.isOpened():
#     print(f"No path 1 - '{video_path_1}'.")
#     exit(1)

# if not cap2.isOpened():
#     print(f"No path 2 - '{video_path_2}'.")
#     exit(1)

frame_count1 = int(cap1.get(cv2.CAP_PROP_FRAME_COUNT))
frame_count2 = int(cap2.get(cv2.CAP_PROP_FRAME_COUNT))

while True:
    ret1, frame1 = cap1.read()
    ret2, frame2 = cap2.read()

    if not ret1:
        cap1.set(cv2.CAP_PROP_POS_FRAMES, 0)
        ret1, frame1 = cap1.read()

    if not ret2:
        cap2.set(cv2.CAP_PROP_POS_FRAMES, 0)
        ret2, frame2 = cap2.read()

    height = min(frame1.shape[0], frame2.shape[0])
    frame1 = cv2.resize(frame1, (int(frame1.shape[1] * height / frame1.shape[0]), height))
    frame2 = cv2.resize(frame2, (int(frame2.shape[1] * height / frame2.shape[0]), height))

    combined_frame = np.hstack((frame1, frame2))

    cv2.imshow('Combined Video', combined_frame)

    if cv2.waitKey(50) & 0xFF == ord('q'):
        break

cap1.release()
cap2.release()
cv2.destroyAllWindows()

# %%
import requests

# ЗАГРУЗКА ФАЙЛА МОДЕЛИ

def download_file(url, local_filename):
    with requests.get(url, stream=True) as r:
        r.raise_for_status()
        with open(local_filename, 'wb') as f:
            for chunk in r.iter_content(chunk_size=8192): 
                f.write(chunk)
    return local_filename

model_url = 'http://places2.csail.mit.edu/models_places365/resnet18_places365.pth.tar'
model_path = 'resnet18_places365.pth.tar'
download_file(model_url, model_path)
# Out:
# 'resnet18_places365.pth.tar'

# %%
import os
import cv2
import torch
import requests
from ultralytics import YOLO
from torchvision import models, transforms
from PIL import Image
from collections import Counter

model_yolo = YOLO('yolov8n.pt')

model_places = models.resnet18(num_classes=365)
checkpoint = torch.hub.load_state_dict_from_url(
    'http://places2.csail.mit.edu/models_places365/resnet18_places365.pth.tar', 
    map_location=lambda storage, loc: storage
)
state_dict = {str.replace(k, 'module.', ''): v for k, v in checkpoint['state_dict'].items()}
model_places.load_state_dict(state_dict)
model_places.eval()

centre_crop = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

LABELS_URL = 'https://raw.githubusercontent.com/csailvision/places365/master/categories_places365.txt'
categories = [line.strip().split(' ')[0][3:] for line in requests.get(LABELS_URL).text.split('\n') if line]

def classify_scene(frame):
    img = Image.fromarray(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    input_img = centre_crop(img).unsqueeze(0)
    logit = model_places(input_img)
    _, predicted = torch.max(logit, 1)
    return categories[predicted.item()]

def process_frame(frame):
    results = model_yolo(frame)
    annotated_frame = results[0].plot()
    objects = results[0].boxes.cls.tolist()
    labels = [model_yolo.names[int(cls)] for cls in objects]
    return annotated_frame, labels

def process_video(video_path, output_path):
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        raise FileNotFoundError(f"Не удается открыть файл {video_path}")

    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    fps = cap.get(cv2.CAP_PROP_FPS)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))
    current_frame = 0
    all_objects = []

    scene_counts = {}

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        current_frame += 1

        annotated_frame, objects = process_frame(frame)
        all_objects.extend(objects)

        scene = classify_scene(frame)
        if scene in scene_counts:
            scene_counts[scene] += 1
        else:
            scene_counts[scene] = 1

        out.write(annotated_frame)

        print(f"Frame num {current_frame} / {total_frames}")
    
    cap.release()
    out.release()
    print(f"Finished. Saved into {output_path}")

    common_scene = max(scene_counts, key=scene_counts.get)
    object_counts = Counter(all_objects)
    detected_objects = ', '.join([f"{obj} ({count})" for obj, count in object_counts.items()])

    print("\n" + "="*50)
    print("Hello!")
    print(f"My data indicates that the video most likely shows: {common_scene}")
    print("I have detected the following objects:")
    print(detected_objects)
    print("="*50 + "\n")
    
video_path = "data/videos/house_1.mov"
output_path = "data/videos/annotation_videos/house_1_1_annotated.mp4"

process_video(video_path, output_path)
# Out:
# 0: 640x352 1 bottle, 2 sinks, 73.8ms
# Speed: 3.0ms preprocess, 73.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 1 / 313
#
# 0: 640x352 1 bottle, 1 sink, 57.9ms
# Speed: 2.0ms preprocess, 57.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 2 / 313
#
# 0: 640x352 1 bottle, 1 sink, 59.8ms
# Speed: 1.0ms preprocess, 59.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 3 / 313
#
# 0: 640x352 1 bottle, 2 sinks, 58.8ms
# Speed: 1.0ms preprocess, 58.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 4 / 313
#
# 0: 640x352 1 bottle, 1 sink, 63.8ms
# Speed: 3.0ms preprocess, 63.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 5 / 313
#
# 0: 640x352 1 bottle, 1 sink, 71.0ms
# Speed: 2.0ms preprocess, 71.0ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 6 / 313
#
# 0: 640x352 1 bottle, 1 sink, 64.0ms
# Speed: 1.5ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 7 / 313
#
# 0: 640x352 1 bottle, 2 sinks, 77.0ms
# Speed: 1.0ms preprocess, 77.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 8 / 313
#
# 0: 640x352 1 bottle, 2 sinks, 84.0ms
# Speed: 2.0ms preprocess, 84.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 9 / 313
#
# 0: 640x352 1 bottle, 2 sinks, 1 refrigerator, 73.0ms
# Speed: 2.0ms preprocess, 73.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 10 / 313
#
# 0: 640x352 1 bottle, 2 sinks, 1 refrigerator, 64.1ms
# Speed: 2.0ms preprocess, 64.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 11 / 313
#
# 0: 640x352 1 bottle, 2 sinks, 1 refrigerator, 63.9ms
# Speed: 1.5ms preprocess, 63.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 12 / 313
#
# 0: 640x352 1 bottle, 2 sinks, 1 refrigerator, 104.5ms
# Speed: 1.5ms preprocess, 104.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 13 / 313
#
# 0: 640x352 1 bottle, 2 sinks, 76.0ms
# Speed: 2.0ms preprocess, 76.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 14 / 313
#
# 0: 640x352 1 bottle, 2 sinks, 1 refrigerator, 59.0ms
# Speed: 1.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 15 / 313
#
# 0: 640x352 1 bottle, 2 sinks, 1 refrigerator, 99.0ms
# Speed: 1.0ms preprocess, 99.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 16 / 313
#
# 0: 640x352 1 bottle, 2 sinks, 1 refrigerator, 87.0ms
# Speed: 2.0ms preprocess, 87.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 17 / 313
#
# 0: 640x352 1 bottle, 2 sinks, 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 18 / 313
#
# 0: 640x352 1 bottle, 2 sinks, 79.9ms
# Speed: 2.0ms preprocess, 79.9ms inference, 3.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 19 / 313
#
# 0: 640x352 1 bottle, 2 sinks, 82.9ms
# Speed: 1.5ms preprocess, 82.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 20 / 313
#
# 0: 640x352 1 bottle, 1 sink, 70.9ms
# Speed: 2.0ms preprocess, 70.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 21 / 313
#
# 0: 640x352 1 bottle, 1 sink, 83.4ms
# Speed: 2.0ms preprocess, 83.4ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 22 / 313
#
# 0: 640x352 1 bottle, 1 cup, 1 sink, 65.0ms
# Speed: 2.0ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 23 / 313
#
# 0: 640x352 1 bottle, 1 cup, 1 sink, 64.0ms
# Speed: 2.0ms preprocess, 64.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 24 / 313
#
# 0: 640x352 1 bottle, 1 sink, 65.0ms
# Speed: 2.0ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 25 / 313
#
# 0: 640x352 1 bottle, 1 sink, 64.0ms
# Speed: 2.0ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 26 / 313
#
# 0: 640x352 1 bottle, 1 cup, 1 sink, 73.8ms
# Speed: 2.0ms preprocess, 73.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 27 / 313
#
# 0: 640x352 1 bottle, 1 sink, 70.0ms
# Speed: 2.0ms preprocess, 70.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 28 / 313
#
# 0: 640x352 1 bottle, 1 sink, 96.3ms
# Speed: 2.0ms preprocess, 96.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 29 / 313
#
# 0: 640x352 1 bottle, 1 sink, 59.8ms
# Speed: 2.0ms preprocess, 59.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 30 / 313
#
# 0: 640x352 1 bottle, 1 sink, 59.8ms
# Speed: 1.0ms preprocess, 59.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 31 / 313
#
# 0: 640x352 1 bottle, 1 sink, 57.9ms
# Speed: 1.0ms preprocess, 57.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 32 / 313
#
# 0: 640x352 1 bottle, 1 sink, 71.8ms
# Speed: 2.0ms preprocess, 71.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 33 / 313
#
# 0: 640x352 1 bottle, 1 sink, 79.3ms
# Speed: 2.0ms preprocess, 79.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 34 / 313
#
# 0: 640x352 1 bottle, 1 sink, 75.8ms
# Speed: 2.0ms preprocess, 75.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 35 / 313
#
# 0: 640x352 1 bottle, 1 sink, 61.0ms
# Speed: 1.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 36 / 313
#
# 0: 640x352 1 bottle, 1 sink, 84.4ms
# Speed: 3.0ms preprocess, 84.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 37 / 313
#
# 0: 640x352 1 bottle, 1 sink, 67.8ms
# Speed: 2.0ms preprocess, 67.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 38 / 313
#
# 0: 640x352 1 bottle, 1 sink, 75.0ms
# Speed: 2.0ms preprocess, 75.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 39 / 313
#
# 0: 640x352 1 bottle, 1 sink, 74.0ms
# Speed: 2.0ms preprocess, 74.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 40 / 313
#
# 0: 640x352 1 bottle, 1 sink, 76.1ms
# Speed: 1.0ms preprocess, 76.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 41 / 313
#
# 0: 640x352 1 bottle, 1 sink, 63.0ms
# Speed: 4.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 42 / 313
#
# 0: 640x352 1 bottle, 1 sink, 66.5ms
# Speed: 2.5ms preprocess, 66.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 43 / 313
#
# 0: 640x352 3 bottles, 1 sink, 1 refrigerator, 62.5ms
# Speed: 3.0ms preprocess, 62.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 44 / 313
#
# 0: 640x352 2 bottles, 1 sink, 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 45 / 313
#
# 0: 640x352 2 bottles, 1 sink, 64.4ms
# Speed: 1.0ms preprocess, 64.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 46 / 313
#
# 0: 640x352 1 bottle, 1 sink, 58.8ms
# Speed: 2.0ms preprocess, 58.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 47 / 313
#
# 0: 640x352 1 bottle, 1 sink, 58.5ms
# Speed: 3.0ms preprocess, 58.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 48 / 313
#
# 0: 640x352 1 bottle, 1 sink, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 49 / 313
#
# 0: 640x352 1 bottle, 1 sink, 92.5ms
# Speed: 2.0ms preprocess, 92.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 50 / 313
#
# 0: 640x352 1 bottle, 1 oven, 1 sink, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 51 / 313
#
# 0: 640x352 1 bottle, 1 sink, 58.4ms
# Speed: 2.0ms preprocess, 58.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 52 / 313
#
# 0: 640x352 1 bottle, 1 sink, 62.8ms
# Speed: 2.0ms preprocess, 62.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 53 / 313
#
# 0: 640x352 1 bottle, 1 sink, 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 54 / 313
#
# 0: 640x352 1 bottle, 1 cup, 1 oven, 1 sink, 58.8ms
# Speed: 2.0ms preprocess, 58.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 55 / 313
#
# 0: 640x352 2 bottles, 1 oven, 1 sink, 59.0ms
# Speed: 1.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 56 / 313
#
# 0: 640x352 2 bottles, 1 oven, 1 sink, 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 57 / 313
#
# 0: 640x352 2 bottles, 1 sink, 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 58 / 313
#
# 0: 640x352 2 bottles, 1 sink, 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 59 / 313
#
# 0: 640x352 2 bottles, 1 sink, 62.8ms
# Speed: 2.0ms preprocess, 62.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 60 / 313
#
# 0: 640x352 2 bottles, 1 bowl, 1 oven, 1 sink, 60.9ms
# Speed: 1.0ms preprocess, 60.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 61 / 313
#
# 0: 640x352 2 bottles, 1 cup, 1 oven, 1 sink, 61.0ms
# Speed: 3.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 62 / 313
#
# 0: 640x352 2 bottles, 1 cup, 1 oven, 1 sink, 65.0ms
# Speed: 1.0ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 63 / 313
#
# 0: 640x352 1 bottle, 1 cup, 1 oven, 1 sink, 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 64 / 313
#
# 0: 640x352 1 bottle, 1 cup, 1 oven, 1 sink, 76.0ms
# Speed: 2.0ms preprocess, 76.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 65 / 313
#
# 0: 640x352 1 bottle, 1 bowl, 1 oven, 1 sink, 60.0ms
# Speed: 3.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 66 / 313
#
# 0: 640x352 1 bottle, 1 bowl, 1 oven, 1 sink, 68.8ms
# Speed: 2.0ms preprocess, 68.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 67 / 313
#
# 0: 640x352 3 bottles, 2 bowls, 1 oven, 1 sink, 61.0ms
# Speed: 1.0ms preprocess, 61.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 68 / 313
#
# 0: 640x352 1 bottle, 2 bowls, 1 oven, 1 sink, 60.5ms
# Speed: 1.5ms preprocess, 60.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 69 / 313
#
# 0: 640x352 1 bottle, 1 bowl, 1 oven, 1 sink, 63.5ms
# Speed: 3.0ms preprocess, 63.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 70 / 313
#
# 0: 640x352 2 bottles, 1 bowl, 1 oven, 1 sink, 69.0ms
# Speed: 2.0ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 71 / 313
#
# 0: 640x352 1 bottle, 1 oven, 1 sink, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 72 / 313
#
# 0: 640x352 2 bottles, 1 bowl, 1 oven, 1 sink, 65.8ms
# Speed: 2.0ms preprocess, 65.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 73 / 313
#
# 0: 640x352 2 bottles, 1 cup, 1 bowl, 1 sink, 64.9ms
# Speed: 1.0ms preprocess, 64.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 74 / 313
#
# 0: 640x352 2 bottles, 1 cup, 1 sink, 62.5ms
# Speed: 2.0ms preprocess, 62.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 75 / 313
#
# 0: 640x352 1 bottle, 1 bowl, 1 oven, 1 sink, 67.5ms
# Speed: 2.0ms preprocess, 67.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 76 / 313
#
# 0: 640x352 1 bottle, 1 cup, 1 bowl, 1 oven, 1 sink, 64.8ms
# Speed: 2.0ms preprocess, 64.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 77 / 313
#
# 0: 640x352 2 bottles, 1 bowl, 1 oven, 1 sink, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 78 / 313
#
# 0: 640x352 2 bottles, 2 bowls, 1 oven, 1 sink, 63.0ms
# Speed: 1.5ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 79 / 313
#
# 0: 640x352 2 bottles, 1 bowl, 1 oven, 1 sink, 89.9ms
# Speed: 2.0ms preprocess, 89.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 80 / 313
#
# 0: 640x352 1 bottle, 1 bowl, 1 oven, 1 sink, 63.0ms
# Speed: 2.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 81 / 313
#
# 0: 640x352 1 bottle, 1 bowl, 1 oven, 1 sink, 61.0ms
# Speed: 1.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 82 / 313
#
# 0: 640x352 1 bottle, 1 cup, 2 bowls, 1 oven, 1 sink, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 83 / 313
#
# 0: 640x352 1 bottle, 1 bowl, 1 oven, 1 sink, 60.4ms
# Speed: 1.5ms preprocess, 60.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 84 / 313
#
# 0: 640x352 2 bottles, 1 bowl, 1 oven, 1 sink, 68.8ms
# Speed: 2.0ms preprocess, 68.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 85 / 313
#
# 0: 640x352 2 bottles, 1 bowl, 1 oven, 1 sink, 59.0ms
# Speed: 3.0ms preprocess, 59.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 86 / 313
#
# 0: 640x352 2 bottles, 1 bowl, 1 oven, 60.1ms
# Speed: 2.5ms preprocess, 60.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 87 / 313
#
# 0: 640x352 1 bottle, 2 bowls, 1 oven, 63.0ms
# Speed: 1.0ms preprocess, 63.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 88 / 313
#
# 0: 640x352 1 bottle, 2 bowls, 1 oven, 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 89 / 313
#
# 0: 640x352 1 bottle, 1 oven, 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 90 / 313
#
# 0: 640x352 2 bottles, 1 bowl, 1 oven, 67.0ms
# Speed: 2.0ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 91 / 313
#
# 0: 640x352 1 bottle, 1 bowl, 1 oven, 66.0ms
# Speed: 1.0ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 92 / 313
#
# 0: 640x352 1 bottle, 1 bowl, 1 oven, 61.4ms
# Speed: 2.0ms preprocess, 61.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 93 / 313
#
# 0: 640x352 1 bottle, 1 oven, 62.8ms
# Speed: 2.0ms preprocess, 62.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 94 / 313
#
# 0: 640x352 1 bottle, 1 oven, 90.0ms
# Speed: 1.5ms preprocess, 90.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 95 / 313
#
# 0: 640x352 1 bottle, 1 oven, 60.5ms
# Speed: 1.5ms preprocess, 60.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 96 / 313
#
# 0: 640x352 1 bottle, 61.5ms
# Speed: 2.0ms preprocess, 61.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 97 / 313
#
# 0: 640x352 1 oven, 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 98 / 313
#
# 0: 640x352 1 bottle, 1 microwave, 1 oven, 64.0ms
# Speed: 1.0ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 99 / 313
#
# 0: 640x352 1 bottle, 1 microwave, 1 oven, 65.0ms
# Speed: 2.0ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 100 / 313
#
# 0: 640x352 2 bottles, 1 bowl, 1 microwave, 1 oven, 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 101 / 313
#
# 0: 640x352 1 bottle, 2 bowls, 1 oven, 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 102 / 313
#
# 0: 640x352 2 bottles, 1 cup, 1 microwave, 1 oven, 69.8ms
# Speed: 2.0ms preprocess, 69.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 103 / 313
#
# 0: 640x352 2 bottles, 1 bowl, 1 microwave, 1 oven, 60.9ms
# Speed: 3.0ms preprocess, 60.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 104 / 313
#
# 0: 640x352 3 bottles, 1 bowl, 1 microwave, 1 oven, 71.0ms
# Speed: 2.0ms preprocess, 71.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 105 / 313
#
# 0: 640x352 1 bottle, 1 cup, 1 bowl, 1 microwave, 1 oven, 1 vase, 75.0ms
# Speed: 2.0ms preprocess, 75.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 106 / 313
#
# 0: 640x352 2 bottles, 1 microwave, 1 oven, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 107 / 313
#
# 0: 640x352 3 bottles, 1 cup, 1 bowl, 1 microwave, 1 oven, 63.5ms
# Speed: 2.0ms preprocess, 63.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 108 / 313
#
# 0: 640x352 2 bottles, 1 bowl, 1 microwave, 1 oven, 72.8ms
# Speed: 2.0ms preprocess, 72.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 109 / 313
#
# 0: 640x352 2 bottles, 1 bowl, 1 microwave, 1 oven, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 110 / 313
#
# 0: 640x352 1 bottle, 2 bowls, 1 microwave, 1 oven, 62.0ms
# Speed: 1.0ms preprocess, 62.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 111 / 313
#
# 0: 640x352 4 bottles, 1 cup, 1 bowl, 1 microwave, 1 oven, 76.5ms
# Speed: 1.0ms preprocess, 76.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 112 / 313
#
# 0: 640x352 3 bottles, 1 cup, 2 bowls, 1 microwave, 2 ovens, 65.8ms
# Speed: 1.0ms preprocess, 65.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 113 / 313
#
# 0: 640x352 2 bottles, 1 bowl, 1 microwave, 1 oven, 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 114 / 313
#
# 0: 640x352 2 bottles, 1 bowl, 1 microwave, 1 oven, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 115 / 313
#
# 0: 640x352 2 bottles, 3 bowls, 1 microwave, 1 oven, 71.5ms
# Speed: 2.0ms preprocess, 71.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 116 / 313
#
# 0: 640x352 3 bottles, 2 bowls, 1 microwave, 1 oven, 72.4ms
# Speed: 1.0ms preprocess, 72.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 117 / 313
#
# 0: 640x352 2 bottles, 3 bowls, 1 microwave, 1 oven, 77.8ms
# Speed: 2.0ms preprocess, 77.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 118 / 313
#
# 0: 640x352 2 bottles, 3 bowls, 1 microwave, 1 oven, 84.0ms
# Speed: 2.0ms preprocess, 84.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 119 / 313
#
# 0: 640x352 3 bottles, 4 bowls, 1 microwave, 1 oven, 73.3ms
# Speed: 1.5ms preprocess, 73.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 120 / 313
#
# 0: 640x352 2 bottles, 3 bowls, 1 microwave, 1 oven, 78.9ms
# Speed: 2.0ms preprocess, 78.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 121 / 313
#
# 0: 640x352 3 bottles, 3 bowls, 1 oven, 75.0ms
# Speed: 2.0ms preprocess, 75.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 122 / 313
#
# 0: 640x352 3 bottles, 4 bowls, 2 microwaves, 1 oven, 73.3ms
# Speed: 2.0ms preprocess, 73.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 123 / 313
#
# 0: 640x352 2 bottles, 4 bowls, 1 microwave, 1 oven, 78.9ms
# Speed: 2.0ms preprocess, 78.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 124 / 313
#
# 0: 640x352 2 bottles, 3 bowls, 1 microwave, 1 oven, 79.0ms
# Speed: 2.0ms preprocess, 79.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 125 / 313
#
# 0: 640x352 2 bottles, 2 bowls, 1 microwave, 1 oven, 78.1ms
# Speed: 2.0ms preprocess, 78.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 126 / 313
#
# 0: 640x352 2 bottles, 3 bowls, 1 microwave, 1 oven, 77.5ms
# Speed: 2.0ms preprocess, 77.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 127 / 313
#
# 0: 640x352 2 bottles, 3 bowls, 1 microwave, 1 oven, 73.4ms
# Speed: 2.0ms preprocess, 73.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 128 / 313
#
# 0: 640x352 2 bottles, 2 bowls, 1 microwave, 1 oven, 62.9ms
# Speed: 2.0ms preprocess, 62.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 129 / 313
#
# 0: 640x352 2 bottles, 3 bowls, 1 microwave, 1 oven, 66.0ms
# Speed: 1.5ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 130 / 313
#
# 0: 640x352 2 bottles, 1 bowl, 1 microwave, 1 oven, 63.0ms
# Speed: 1.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 131 / 313
#
# 0: 640x352 2 bottles, 4 bowls, 1 microwave, 1 oven, 61.0ms
# Speed: 1.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 132 / 313
#
# 0: 640x352 2 bottles, 3 bowls, 1 microwave, 1 oven, 60.4ms
# Speed: 2.0ms preprocess, 60.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 133 / 313
#
# 0: 640x352 3 bottles, 3 bowls, 1 microwave, 1 oven, 66.8ms
# Speed: 1.0ms preprocess, 66.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 134 / 313
#
# 0: 640x352 2 bottles, 2 bowls, 1 microwave, 1 oven, 64.9ms
# Speed: 1.0ms preprocess, 64.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 135 / 313
#
# 0: 640x352 4 bottles, 3 bowls, 1 microwave, 1 oven, 61.0ms
# Speed: 3.0ms preprocess, 61.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 136 / 313
#
# 0: 640x352 2 bottles, 2 bowls, 1 microwave, 1 oven, 63.0ms
# Speed: 1.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 137 / 313
#
# 0: 640x352 3 bottles, 2 bowls, 1 microwave, 1 oven, 63.0ms
# Speed: 2.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 138 / 313
#
# 0: 640x352 3 bottles, 2 bowls, 1 microwave, 1 oven, 63.0ms
# Speed: 2.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 139 / 313
#
# 0: 640x352 1 bottle, 2 bowls, 1 microwave, 1 oven, 74.0ms
# Speed: 2.0ms preprocess, 74.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 140 / 313
#
# 0: 640x352 1 bottle, 2 bowls, 1 microwave, 64.0ms
# Speed: 1.0ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 141 / 313
#
# 0: 640x352 1 bottle, 1 bowl, 1 microwave, 1 oven, 69.4ms
# Speed: 2.0ms preprocess, 69.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 142 / 313
#
# 0: 640x352 1 bottle, 1 bowl, 1 microwave, 1 oven, 62.8ms
# Speed: 1.0ms preprocess, 62.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 143 / 313
#
# 0: 640x352 1 bottle, 1 bowl, 1 microwave, 59.0ms
# Speed: 1.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 144 / 313
#
# 0: 640x352 1 bowl, 1 microwave, 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 145 / 313
#
# 0: 640x352 1 bowl, 1 microwave, 58.9ms
# Speed: 3.0ms preprocess, 58.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 146 / 313
#
# 0: 640x352 1 bowl, 1 microwave, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 147 / 313
#
# 0: 640x352 1 bowl, 1 microwave, 64.0ms
# Speed: 2.0ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 148 / 313
#
# 0: 640x352 1 bowl, 1 microwave, 65.0ms
# Speed: 2.1ms preprocess, 65.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 149 / 313
#
# 0: 640x352 1 bowl, 1 microwave, 63.0ms
# Speed: 2.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 150 / 313
#
# 0: 640x352 1 bowl, 1 microwave, 64.5ms
# Speed: 1.5ms preprocess, 64.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 151 / 313
#
# 0: 640x352 1 bottle, 1 bowl, 1 microwave, 60.0ms
# Speed: 1.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 152 / 313
#
# 0: 640x352 1 bowl, 1 microwave, 62.8ms
# Speed: 4.0ms preprocess, 62.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 153 / 313
#
# 0: 640x352 1 bottle, 1 bowl, 1 microwave, 1 sink, 61.9ms
# Speed: 2.0ms preprocess, 61.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 154 / 313
#
# 0: 640x352 1 bowl, 1 microwave, 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 155 / 313
#
# 0: 640x352 1 bowl, 1 microwave, 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 156 / 313
#
# 0: 640x352 2 bottles, 1 bowl, 1 microwave, 66.8ms
# Speed: 2.0ms preprocess, 66.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 157 / 313
#
# 0: 640x352 3 bottles, 1 bowl, 1 microwave, 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 158 / 313
#
# 0: 640x352 3 bottles, 1 bowl, 1 microwave, 60.0ms
# Speed: 1.0ms preprocess, 60.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 159 / 313
#
# 0: 640x352 3 bottles, 1 bowl, 1 microwave, 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 160 / 313
#
# 0: 640x352 1 bottle, 1 bowl, 71.0ms
# Speed: 2.0ms preprocess, 71.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 161 / 313
#
# 0: 640x352 2 bottles, 1 bowl, 73.0ms
# Speed: 2.0ms preprocess, 73.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 162 / 313
#
# 0: 640x352 2 bottles, 1 bowl, 60.8ms
# Speed: 2.0ms preprocess, 60.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 163 / 313
#
# 0: 640x352 4 bottles, 1 bowl, 62.9ms
# Speed: 1.0ms preprocess, 62.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 164 / 313
#
# 0: 640x352 2 bottles, 1 bowl, 61.1ms
# Speed: 2.0ms preprocess, 61.1ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 165 / 313
#
# 0: 640x352 2 bottles, 1 bowl, 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 166 / 313
#
# 0: 640x352 3 bottles, 1 cup, 1 bowl, 64.0ms
# Speed: 2.0ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 167 / 313
#
# 0: 640x352 4 bottles, 1 chair, 67.0ms
# Speed: 1.0ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 168 / 313
#
# 0: 640x352 3 bottles, 1 cup, 1 chair, 61.5ms
# Speed: 2.0ms preprocess, 61.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 169 / 313
#
# 0: 640x352 2 bottles, 1 cup, 1 chair, 68.0ms
# Speed: 2.1ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 170 / 313
#
# 0: 640x352 4 bottles, 2 cups, 1 chair, 64.0ms
# Speed: 2.0ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 171 / 313
#
# 0: 640x352 4 bottles, 1 chair, 66.8ms
# Speed: 6.0ms preprocess, 66.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 172 / 313
#
# 0: 640x352 5 bottles, 2 cups, 1 chair, 62.0ms
# Speed: 1.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 173 / 313
#
# 0: 640x352 4 bottles, 1 cup, 1 chair, 64.5ms
# Speed: 1.0ms preprocess, 64.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 174 / 313
#
# 0: 640x352 3 bottles, 1 cup, 1 chair, 66.0ms
# Speed: 1.0ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 175 / 313
#
# 0: 640x352 4 bottles, 2 cups, 1 chair, 63.0ms
# Speed: 1.0ms preprocess, 63.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 176 / 313
#
# 0: 640x352 3 bottles, 1 cup, 1 chair, 62.0ms
# Speed: 1.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 177 / 313
#
# 0: 640x352 3 bottles, 1 cup, 1 chair, 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 178 / 313
#
# 0: 640x352 4 bottles, 2 cups, 1 chair, 62.4ms
# Speed: 1.0ms preprocess, 62.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 179 / 313
#
# 0: 640x352 3 bottles, 2 cups, 1 chair, 60.8ms
# Speed: 2.0ms preprocess, 60.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 180 / 313
#
# 0: 640x352 3 bottles, 1 cup, 1 chair, 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 181 / 313
#
# 0: 640x352 4 bottles, 1 cup, 1 chair, 65.0ms
# Speed: 2.0ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 182 / 313
#
# 0: 640x352 5 bottles, 2 cups, 1 chair, 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 183 / 313
#
# 0: 640x352 2 bottles, 2 cups, 1 chair, 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 184 / 313
#
# 0: 640x352 3 bottles, 2 cups, 2 chairs, 62.0ms
# Speed: 1.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 185 / 313
#
# 0: 640x352 3 bottles, 1 cup, 2 chairs, 60.3ms
# Speed: 2.0ms preprocess, 60.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 186 / 313
#
# 0: 640x352 4 bottles, 1 cup, 1 chair, 66.9ms
# Speed: 2.0ms preprocess, 66.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 187 / 313
#
# 0: 640x352 4 bottles, 1 cup, 1 chair, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 188 / 313
#
# 0: 640x352 3 bottles, 3 cups, 1 chair, 74.0ms
# Speed: 2.0ms preprocess, 74.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 189 / 313
#
# 0: 640x352 3 bottles, 1 cup, 1 chair, 1 dining table, 1 vase, 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 190 / 313
#
# 0: 640x352 3 bottles, 2 cups, 1 chair, 1 dining table, 81.0ms
# Speed: 2.0ms preprocess, 81.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 191 / 313
#
# 0: 640x352 3 bottles, 3 cups, 1 chair, 1 dining table, 84.5ms
# Speed: 2.0ms preprocess, 84.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 192 / 313
#
# 0: 640x352 4 bottles, 1 cup, 1 chair, 1 dining table, 81.0ms
# Speed: 1.5ms preprocess, 81.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 193 / 313
#
# 0: 640x352 4 bottles, 5 cups, 1 chair, 1 dining table, 72.0ms
# Speed: 1.5ms preprocess, 72.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 194 / 313
#
# 0: 640x352 3 bottles, 4 cups, 1 spoon, 1 chair, 1 dining table, 92.3ms
# Speed: 2.0ms preprocess, 92.3ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 195 / 313
#
# 0: 640x352 4 bottles, 4 cups, 1 chair, 1 dining table, 67.9ms
# Speed: 1.0ms preprocess, 67.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 196 / 313
#
# 0: 640x352 4 bottles, 4 cups, 1 bowl, 1 chair, 1 dining table, 61.5ms
# Speed: 1.5ms preprocess, 61.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 197 / 313
#
# 0: 640x352 2 bottles, 4 cups, 1 chair, 1 dining table, 62.0ms
# Speed: 1.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 198 / 313
#
# 0: 640x352 4 bottles, 4 cups, 1 spoon, 1 bowl, 1 chair, 1 dining table, 60.0ms
# Speed: 2.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 199 / 313
#
# 0: 640x352 4 bottles, 5 cups, 1 spoon, 1 bowl, 1 chair, 1 dining table, 60.9ms
# Speed: 1.1ms preprocess, 60.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 200 / 313
#
# 0: 640x352 4 bottles, 5 cups, 2 spoons, 1 bowl, 1 chair, 1 dining table, 82.0ms
# Speed: 2.0ms preprocess, 82.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 201 / 313
#
# 0: 640x352 3 bottles, 4 cups, 3 spoons, 1 bowl, 1 chair, 1 dining table, 93.0ms
# Speed: 2.0ms preprocess, 93.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 202 / 313
#
# 0: 640x352 3 bottles, 3 cups, 4 spoons, 1 bowl, 1 chair, 1 dining table, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 203 / 313
#
# 0: 640x352 2 bottles, 4 cups, 1 bowl, 1 chair, 1 dining table, 61.8ms
# Speed: 2.0ms preprocess, 61.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 204 / 313
#
# 0: 640x352 2 bottles, 5 cups, 1 bowl, 1 chair, 1 dining table, 59.9ms
# Speed: 2.0ms preprocess, 59.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 205 / 313
#
# 0: 640x352 2 bottles, 5 cups, 1 bowl, 2 chairs, 1 dining table, 61.0ms
# Speed: 1.5ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 206 / 313
#
# 0: 640x352 3 bottles, 4 cups, 2 spoons, 1 bowl, 1 chair, 1 dining table, 67.5ms
# Speed: 2.0ms preprocess, 67.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 207 / 313
#
# 0: 640x352 1 bottle, 5 cups, 1 bowl, 1 chair, 1 dining table, 60.4ms
# Speed: 2.0ms preprocess, 60.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 208 / 313
#
# 0: 640x352 1 bottle, 5 cups, 1 spoon, 1 bowl, 1 chair, 1 dining table, 91.8ms
# Speed: 1.0ms preprocess, 91.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 209 / 313
#
# 0: 640x352 2 bottles, 5 cups, 1 bowl, 1 chair, 1 dining table, 64.0ms
# Speed: 1.0ms preprocess, 64.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 210 / 313
#
# 0: 640x352 1 person, 2 bottles, 4 cups, 2 bowls, 1 chair, 1 dining table, 63.0ms
# Speed: 1.0ms preprocess, 63.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 211 / 313
#
# 0: 640x352 1 person, 2 bottles, 5 cups, 2 bowls, 1 chair, 1 dining table, 69.0ms
# Speed: 1.0ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 212 / 313
#
# 0: 640x352 1 bottle, 4 cups, 1 spoon, 2 bowls, 1 chair, 1 dining table, 63.0ms
# Speed: 1.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 213 / 313
#
# 0: 640x352 4 cups, 1 knife, 1 bowl, 1 chair, 1 dining table, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 214 / 313
#
# 0: 640x352 4 cups, 2 bowls, 1 chair, 1 dining table, 62.0ms
# Speed: 1.9ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 215 / 313
#
# 0: 640x352 5 cups, 2 bowls, 1 chair, 67.8ms
# Speed: 2.0ms preprocess, 67.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 216 / 313
#
# 0: 640x352 4 cups, 2 bowls, 1 chair, 1 dining table, 71.0ms
# Speed: 2.0ms preprocess, 71.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 217 / 313
#
# 0: 640x352 4 cups, 3 bowls, 1 chair, 1 dining table, 62.0ms
# Speed: 1.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 218 / 313
#
# 0: 640x352 4 cups, 1 bowl, 1 chair, 63.0ms
# Speed: 2.0ms preprocess, 63.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 219 / 313
#
# 0: 640x352 4 cups, 1 spoon, 2 bowls, 2 chairs, 1 dining table, 65.0ms
# Speed: 2.0ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 220 / 313
#
# 0: 640x352 4 cups, 2 bowls, 2 chairs, 63.0ms
# Speed: 1.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 221 / 313
#
# 0: 640x352 4 cups, 2 bowls, 1 chair, 65.0ms
# Speed: 2.0ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 222 / 313
#
# 0: 640x352 4 cups, 1 bowl, 2 chairs, 65.0ms
# Speed: 2.0ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 223 / 313
#
# 0: 640x352 4 cups, 2 bowls, 1 chair, 60.8ms
# Speed: 1.0ms preprocess, 60.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 224 / 313
#
# 0: 640x352 4 cups, 1 spoon, 2 bowls, 1 chair, 68.9ms
# Speed: 2.0ms preprocess, 68.9ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 225 / 313
#
# 0: 640x352 4 cups, 1 spoon, 2 bowls, 1 chair, 1 dining table, 60.4ms
# Speed: 1.0ms preprocess, 60.4ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 226 / 313
#
# 0: 640x352 4 cups, 2 bowls, 1 chair, 60.8ms
# Speed: 2.0ms preprocess, 60.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 227 / 313
#
# 0: 640x352 4 cups, 2 spoons, 2 bowls, 1 chair, 69.0ms
# Speed: 2.0ms preprocess, 69.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 228 / 313
#
# 0: 640x352 4 cups, 1 spoon, 2 bowls, 1 chair, 1 dining table, 63.5ms
# Speed: 2.0ms preprocess, 63.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 229 / 313
#
# 0: 640x352 5 cups, 2 bowls, 60.0ms
# Speed: 1.5ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 230 / 313
#
# 0: 640x352 5 cups, 1 spoon, 2 bowls, 1 chair, 1 dining table, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 231 / 313
#
# 0: 640x352 5 cups, 1 spoon, 2 bowls, 1 dining table, 64.0ms
# Speed: 2.0ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 232 / 313
#
# 0: 640x352 5 cups, 1 spoon, 2 bowls, 1 dining table, 65.0ms
# Speed: 2.0ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 233 / 313
#
# 0: 640x352 5 cups, 1 spoon, 2 bowls, 1 dining table, 63.8ms
# Speed: 2.0ms preprocess, 63.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 234 / 313
#
# 0: 640x352 4 cups, 1 spoon, 2 bowls, 1 dining table, 65.0ms
# Speed: 1.0ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 235 / 313
#
# 0: 640x352 5 cups, 1 spoon, 2 bowls, 1 dining table, 61.0ms
# Speed: 1.5ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 236 / 313
#
# 0: 640x352 4 cups, 1 spoon, 2 bowls, 1 dining table, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 237 / 313
#
# 0: 640x352 5 cups, 1 spoon, 2 bowls, 1 dining table, 61.8ms
# Speed: 1.0ms preprocess, 61.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 238 / 313
#
# 0: 640x352 5 cups, 1 knife, 1 spoon, 2 bowls, 1 dining table, 70.0ms
# Speed: 2.0ms preprocess, 70.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 239 / 313
#
# 0: 640x352 4 cups, 2 spoons, 2 bowls, 1 dining table, 73.0ms
# Speed: 2.0ms preprocess, 73.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 240 / 313
#
# 0: 640x352 5 cups, 3 spoons, 2 bowls, 1 dining table, 66.0ms
# Speed: 1.0ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 241 / 313
#
# 0: 640x352 4 cups, 1 spoon, 2 bowls, 1 chair, 1 dining table, 67.5ms
# Speed: 2.0ms preprocess, 67.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 242 / 313
#
# 0: 640x352 5 cups, 2 bowls, 1 dining table, 79.0ms
# Speed: 2.0ms preprocess, 79.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 243 / 313
#
# 0: 640x352 5 cups, 1 bowl, 1 dining table, 71.8ms
# Speed: 2.0ms preprocess, 71.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 244 / 313
#
# 0: 640x352 4 cups, 1 bowl, 2 chairs, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 245 / 313
#
# 0: 640x352 3 cups, 1 knife, 2 bowls, 2 chairs, 1 dining table, 62.5ms
# Speed: 2.5ms preprocess, 62.5ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 246 / 313
#
# 0: 640x352 3 cups, 1 spoon, 1 bowl, 1 dining table, 61.0ms
# Speed: 1.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 247 / 313
#
# 0: 640x352 3 cups, 1 spoon, 1 bowl, 1 chair, 1 dining table, 63.0ms
# Speed: 2.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 248 / 313
#
# 0: 640x352 3 cups, 1 bowl, 1 chair, 1 clock, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 249 / 313
#
# 0: 640x352 2 cups, 1 spoon, 1 bowl, 1 chair, 60.0ms
# Speed: 1.5ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 250 / 313
#
# 0: 640x352 3 cups, 1 spoon, 1 chair, 1 dining table, 69.0ms
# Speed: 2.0ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 251 / 313
#
# 0: 640x352 1 bowl, 1 toilet, 60.0ms
# Speed: 1.0ms preprocess, 60.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 252 / 313
#
# 0: 640x352 (no detections), 66.0ms
# Speed: 1.0ms preprocess, 66.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 253 / 313
#
# 0: 640x352 1 bowl, 59.5ms
# Speed: 2.5ms preprocess, 59.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 254 / 313
#
# 0: 640x352 1 bowl, 1 chair, 59.4ms
# Speed: 2.0ms preprocess, 59.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 255 / 313
#
# 0: 640x352 1 chair, 93.8ms
# Speed: 2.0ms preprocess, 93.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 256 / 313
#
# 0: 640x352 1 chair, 65.0ms
# Speed: 1.0ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 257 / 313
#
# 0: 640x352 1 chair, 62.0ms
# Speed: 3.0ms preprocess, 62.0ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 258 / 313
#
# 0: 640x352 1 chair, 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 259 / 313
#
# 0: 640x352 1 chair, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 260 / 313
#
# 0: 640x352 1 cake, 1 chair, 67.0ms
# Speed: 3.0ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 261 / 313
#
# 0: 640x352 (no detections), 75.8ms
# Speed: 3.0ms preprocess, 75.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 262 / 313
#
# 0: 640x352 1 chair, 59.0ms
# Speed: 2.0ms preprocess, 59.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 263 / 313
#
# 0: 640x352 1 cat, 1 cake, 1 chair, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 264 / 313
#
# 0: 640x352 1 cat, 1 chair, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 265 / 313
#
# 0: 640x352 1 cat, 1 chair, 66.5ms
# Speed: 2.0ms preprocess, 66.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 266 / 313
#
# 0: 640x352 1 cat, 1 chair, 1 book, 95.0ms
# Speed: 1.5ms preprocess, 95.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 267 / 313
#
# 0: 640x352 1 cat, 1 dog, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 268 / 313
#
# 0: 640x352 1 chair, 60.5ms
# Speed: 1.5ms preprocess, 60.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 269 / 313
#
# 0: 640x352 1 cat, 64.0ms
# Speed: 2.0ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 270 / 313
#
# 0: 640x352 (no detections), 64.8ms
# Speed: 1.0ms preprocess, 64.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 271 / 313
#
# 0: 640x352 (no detections), 93.0ms
# Speed: 1.0ms preprocess, 93.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 272 / 313
#
# 0: 640x352 (no detections), 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 273 / 313
#
# 0: 640x352 (no detections), 61.8ms
# Speed: 4.0ms preprocess, 61.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 274 / 313
#
# 0: 640x352 (no detections), 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 275 / 313
#
# 0: 640x352 (no detections), 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 276 / 313
#
# 0: 640x352 (no detections), 107.5ms
# Speed: 1.5ms preprocess, 107.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 277 / 313
#
# 0: 640x352 (no detections), 68.6ms
# Speed: 2.5ms preprocess, 68.6ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 278 / 313
#
# 0: 640x352 (no detections), 60.5ms
# Speed: 1.5ms preprocess, 60.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 279 / 313
#
# 0: 640x352 (no detections), 61.0ms
# Speed: 1.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 280 / 313
#
# 0: 640x352 (no detections), 67.5ms
# Speed: 2.0ms preprocess, 67.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 281 / 313
#
# 0: 640x352 1 vase, 67.0ms
# Speed: 2.0ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 282 / 313
#
# 0: 640x352 1 umbrella, 65.9ms
# Speed: 2.0ms preprocess, 65.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 283 / 313
#
# 0: 640x352 1 vase, 61.5ms
# Speed: 2.5ms preprocess, 61.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 284 / 313
#
# 0: 640x352 (no detections), 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 285 / 313
#
# 0: 640x352 (no detections), 77.0ms
# Speed: 2.0ms preprocess, 77.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 286 / 313
#
# 0: 640x352 (no detections), 60.8ms
# Speed: 2.0ms preprocess, 60.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 287 / 313
#
# 0: 640x352 1 umbrella, 64.0ms
# Speed: 1.5ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 288 / 313
#
# 0: 640x352 (no detections), 140.5ms
# Speed: 1.5ms preprocess, 140.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 289 / 313
#
# 0: 640x352 (no detections), 66.3ms
# Speed: 1.0ms preprocess, 66.3ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 290 / 313
#
# 0: 640x352 (no detections), 62.9ms
# Speed: 2.0ms preprocess, 62.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 291 / 313
#
# 0: 640x352 (no detections), 65.5ms
# Speed: 2.0ms preprocess, 65.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 292 / 313
#
# 0: 640x352 (no detections), 66.9ms
# Speed: 2.0ms preprocess, 66.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 293 / 313
#
# 0: 640x352 (no detections), 62.0ms
# Speed: 1.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 294 / 313
#
# 0: 640x352 (no detections), 61.5ms
# Speed: 1.5ms preprocess, 61.5ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 295 / 313
#
# 0: 640x352 (no detections), 91.0ms
# Speed: 1.5ms preprocess, 91.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 296 / 313
#
# 0: 640x352 (no detections), 66.4ms
# Speed: 2.0ms preprocess, 66.4ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 297 / 313
#
# 0: 640x352 (no detections), 61.8ms
# Speed: 2.0ms preprocess, 61.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 298 / 313
#
# 0: 640x352 (no detections), 67.0ms
# Speed: 1.0ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 299 / 313
#
# 0: 640x352 (no detections), 61.9ms
# Speed: 2.0ms preprocess, 61.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 300 / 313
#
# 0: 640x352 (no detections), 64.5ms
# Speed: 2.5ms preprocess, 64.5ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 301 / 313
#
# 0: 640x352 (no detections), 92.0ms
# Speed: 2.5ms preprocess, 92.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 302 / 313
#
# 0: 640x352 (no detections), 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 303 / 313
#
# 0: 640x352 (no detections), 62.8ms
# Speed: 2.0ms preprocess, 62.8ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 304 / 313
#
# 0: 640x352 (no detections), 93.9ms
# Speed: 1.0ms preprocess, 93.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 305 / 313
#
# 0: 640x352 (no detections), 65.0ms
# Speed: 2.0ms preprocess, 65.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 306 / 313
#
# 0: 640x352 (no detections), 63.0ms
# Speed: 2.0ms preprocess, 63.0ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 307 / 313
#
# 0: 640x352 (no detections), 61.5ms
# Speed: 2.0ms preprocess, 61.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 308 / 313
#
# 0: 640x352 (no detections), 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 309 / 313
#
# 0: 640x352 (no detections), 71.3ms
# Speed: 1.5ms preprocess, 71.3ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 310 / 313
#
# 0: 640x352 (no detections), 70.9ms
# Speed: 2.0ms preprocess, 70.9ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 311 / 313
#
# 0: 640x352 (no detections), 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 312 / 313
#
# 0: 640x352 (no detections), 65.0ms
# Speed: 2.0ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 352)
# Frame num 313 / 313
# Finished. Saved into data/videos/annotation_videos/house_1_1_annotated.mp4
#
# ==================================================
# Hello!
# My data indicates that the video most likely shows: kitchen
# I have detected the following objects:
# sink (102), bottle (390), refrigerator (8), cup (300), oven (84), bowl (233), microwave (61), vase (4), chair (91), dining table (49), spoon (41), person (2), knife (3), clock (1), toilet (1), cake (2), cat (6), book (1), dog (1), umbrella (2)
# ==================================================
